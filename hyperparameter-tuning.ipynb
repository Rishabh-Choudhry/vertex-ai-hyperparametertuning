# %%
! pip3 install --upgrade google-cloud-aiplatform

# %% [markdown]
# ### Set project ID, location, and GCS Bucket

# %%
PROJECT_ID = "GCP_PROJECT"
LOCATION = "GCP_LOCATION"
GCS_BUCKET = "GCS_BUCKET"

# %%
from google.cloud import aiplatform
from google.cloud.aiplatform import hyperparameter_tuning as hpt
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Initialise the AI platform sdk

# %%
aiplatform.init(project=PROJECT_ID, location=LOCATION, staging_bucket=GCS_BUCKET)

# %% [markdown]
# ### Setup docker image of XGBoost ( publicly available)

# %%
TRAIN_VERSION = "xgboost-cpu.1-6"
DEPLOY_VERSION = "xgboost-cpu.1-6"

TRAIN_IMAGE = "{}-docker.pkg.dev/vertex-ai/training/{}:latest".format(
    LOCATION.split("-")[0], TRAIN_VERSION
)
DEPLOY_IMAGE = "{}-docker.pkg.dev/vertex-ai/prediction/{}:latest".format(
    LOCATION.split("-")[0], DEPLOY_VERSION
)

# %% [markdown]
# ### Copy the hyperparametertuning code to cloud storage

# %%
! rm -f boston-data-trainer.tar boston-data-trainer.tar.gz
! tar cvf boston-data-trainer.tar boston-data-trainer
! gzip boston-data-trainer.tar
! gsutil cp boston-data-trainer.tar.gz $GCS_BUCKET/
# Out:
# boston-data-trainer/
# boston-data-trainer/README.md
# boston-data-trainer/setup.py
# boston-data-trainer/trainer/
# boston-data-trainer/trainer/__init__.py
# boston-data-trainer/trainer/.ipynb_checkpoints/
# boston-data-trainer/trainer/.ipynb_checkpoints/train-checkpoint.py
# boston-data-trainer/trainer/train.py
# boston-data-trainer/PKG-INFO
# boston-data-trainer/setup.cfg
# Copying file://boston-data-trainer.tar.gz [Content-Type=application/x-tar]...
# / [1 files][  2.1 KiB/  2.1 KiB]
# Operation completed over 1 objects/2.1 KiB.

# %% [markdown]
# # Set disk type, disk size, machine spec for hyperparametertuning worker pool

# %%
DISK_TYPE = "pd-ssd"  # [ pd-ssd, pd-standard]
DISK_SIZE = 100  # GB
COMPUTE_MACHINE = "n1-standard-4"
machine_spec = {"machine_type": COMPUTE_MACHINE, "accelerator_count": 0}
disk_spec = {"boot_disk_type": DISK_TYPE, "boot_disk_size_gb": DISK_SIZE}

# %%
# Set path to save model
MODEL_DIR = "{}/aiplatform-custom-job".format(GCS_BUCKET)
# Set the source path to the dataset
DATASET_DIR = f"{GCS_BUCKET}/dataset"

# Set the command-line arguments
ARGS = [
    "--dataset-data-url=" + DATASET_DIR + "/data.csv",
    "--dataset-labels-url=" + DATASET_DIR + "/target.csv",
]

# Set the worker pool specs
worker_pool_spec = [
    {
        "replica_count": 1,
        "machine_spec": machine_spec,
        "disk_spec": disk_spec,
        "python_package_spec": {
            "executor_image_uri": TRAIN_IMAGE,
            "package_uris": [GCS_BUCKET + "/boston-data-trainer.tar.gz"],
            "python_module": "trainer.train",
            "args": ARGS,
        },
    }
    
]

# %% [markdown]
# # Launch hyperparametertuning job

# %%
job = aiplatform.CustomJob(
    display_name="boston",
    worker_pool_specs=worker_pool_spec,
    base_output_dir=MODEL_DIR,
)

# %% [markdown]
# ### Setup hyperparameter tuning parameters
# ### Use default search algorithm (Bayesian)

# %%
hpt_job = aiplatform.HyperparameterTuningJob(
    display_name="Boston Housing",
    custom_job=job,
    metric_spec={
        "mean_squared_error": "minimize",
    },
    parameter_spec={
        "n-estimators": hpt.IntegerParameterSpec(min=50, max=150, scale="linear"),
        "max-depth": hpt.IntegerParameterSpec(min=3, max=7, scale="linear"),
        "learning-rate": hpt.DoubleParameterSpec(min=0.01, max=0.2, scale="log"),
        "subsample": hpt.DoubleParameterSpec(min=0.3, max=0.9, scale="linear"),
    },
    search_algorithm=None,
    max_trial_count=20,
    parallel_trial_count=4,
)

# %%
hpt_job.run()
# Out:
# Creating HyperparameterTuningJob
# HyperparameterTuningJob created. Resource name: projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912
# To use this HyperparameterTuningJob in another session:
# hpt_job = aiplatform.HyperparameterTuningJob.get('projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912')
# View HyperparameterTuningJob:
# https://console.cloud.google.com/ai/platform/locations/us-central1/training/8907984101454118912?project=163391326695
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_PENDING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_PENDING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_PENDING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# ...
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912 current state:
# JobState.JOB_STATE_SUCCEEDED
# HyperparameterTuningJob run completed. Resource name: projects/163391326695/locations/us-central1/hyperparameterTuningJobs/8907984101454118912

# %%
print(hpt_job.trials)
# Out:
# [id: "1"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.04472135954999579
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 5.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 100.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.6000000000000001
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 19.513283731437348
#   }
# }
# start_time {
#   seconds: 1729766367
#   nanos: 920411993
# }
# end_time {
#   seconds: 1729766708
# }
# , id: "2"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.0840938675925055
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 5.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 81.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.5290918676298215
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 17.968395319950766
#   }
# }
# start_time {
#   seconds: 1729766367
#   nanos: 920641781
# }
# end_time {
#   seconds: 1729766696
# }
# , id: "3"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.05980550369697237
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 5.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 104.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.436158350536158
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 17.86844433457207
#   }
# }
# start_time {
#   seconds: 1729766367
#   nanos: 920719725
# }
# end_time {
#   seconds: 1729766701
# }
# , id: "4"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.03395687226258812
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 5.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 78.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.532801560154126
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 30.53748105743811
#   }
# }
# start_time {
#   seconds: 1729766367
#   nanos: 920777380
# }
# end_time {
#   seconds: 1729766703
# }
# , id: "5"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.08503169437788859
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 5.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 124.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.7482259360892836
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 18.36086365942341
#   }
# }
# start_time {
#   seconds: 1729766836
#   nanos: 628239776
# }
# end_time {
#   seconds: 1729766919
# }
# , id: "6"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.07245428009302876
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 3.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 99.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.35328015648584
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 17.883876820458653
#   }
# }
# start_time {
#   seconds: 1729766839
#   nanos: 130542752
# }
# end_time {
#   seconds: 1729766921
# }
# , id: "7"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.06793628150660809
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 3.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 96.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.8092916472225786
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 18.92491334806879
#   }
# }
# start_time {
#   seconds: 1729766839
#   nanos: 130747444
# }
# end_time {
#   seconds: 1729767109
# }
# , id: "8"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.11117540967587292
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 3.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 128.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.3008784076506272
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 14.953580245548158
#   }
# }
# start_time {
#   seconds: 1729766841
#   nanos: 136065297
# }
# end_time {
#   seconds: 1729767100
# }
# , id: "9"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.06484886444779094
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 5.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 97.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.3104223949710387
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 16.967382413322905
#   }
# }
# start_time {
#   seconds: 1729767171
#   nanos: 781076101
# }
# end_time {
#   seconds: 1729767263
# }
# , id: "10"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.08508397686491559
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 7.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 100.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.3249604279516316
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 15.759086721915114
#   }
# }
# start_time {
#   seconds: 1729767171
#   nanos: 781271618
# }
# end_time {
#   seconds: 1729767254
# }
# , id: "11"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.16912794332957254
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 5.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 128.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.3
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 20.370617049064524
#   }
# }
# start_time {
#   seconds: 1729767305
#   nanos: 350676758
# }
# end_time {
#   seconds: 1729767569
# }
# , id: "12"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.09833311462717587
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 4.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 150.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.3
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 16.296740787318043
#   }
# }
# start_time {
#   seconds: 1729767305
#   nanos: 350871143
# }
# end_time {
#   seconds: 1729767565
# }
# , id: "13"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.19999999999999996
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 3.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 150.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.3
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 21.491308651017935
#   }
# }
# start_time {
#   seconds: 1729767506
#   nanos: 441040999
# }
# end_time {
#   seconds: 1729767778
# }
# , id: "14"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.19995579903468258
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 6.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 150.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.41409983653985305
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 20.2981973474294
#   }
# }
# start_time {
#   seconds: 1729767506
#   nanos: 441197263
# }
# end_time {
#   seconds: 1729767790
# }
# , id: "15"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.12537519734154118
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 3.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 63.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.3
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 15.90972885569854
#   }
# }
# start_time {
#   seconds: 1729767709
#   nanos: 103438998
# }
# end_time {
#   seconds: 1729767973
# }
# , id: "16"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.124115210767578
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 3.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 133.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.9
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 18.029679305748026
#   }
# }
# start_time {
#   seconds: 1729767714
#   nanos: 82955480
# }
# end_time {
#   seconds: 1729767982
# }
# , id: "17"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.10831287870710962
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 7.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 101.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.3
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 15.681901285948909
#   }
# }
# start_time {
#   seconds: 1729767948
#   nanos: 775692452
# }
# end_time {
#   seconds: 1729768218
# }
# , id: "18"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.1012960594899324
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 3.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 55.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.3
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 16.720469388279223
#   }
# }
# start_time {
#   seconds: 1729767948
#   nanos: 775467739
# }
# end_time {
#   seconds: 1729768240
# }
# , id: "19"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.11410963598578237
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 3.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 150.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.3
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 15.395284089547996
#   }
# }
# start_time {
#   seconds: 1729768116
#   nanos: 917725098
# }
# end_time {
#   seconds: 1729768408
# }
# , id: "20"
# state: SUCCEEDED
# parameters {
#   parameter_id: "learning-rate"
#   value {
#     number_value: 0.11471644617367358
#   }
# }
# parameters {
#   parameter_id: "max-depth"
#   value {
#     number_value: 5.0
#   }
# }
# parameters {
#   parameter_id: "n-estimators"
#   value {
#     number_value: 56.0
#   }
# }
# parameters {
#   parameter_id: "subsample"
#   value {
#     number_value: 0.4655238168089061
#   }
# }
# final_measurement {
#   step_count: 1
#   metrics {
#     metric_id: "mean_squared_error"
#     value: 16.90190121940362
#   }
# }
# start_time {
#   seconds: 1729768120
#   nanos: 902238917
# }
# end_time {
#   seconds: 1729768390
# }
# ]

# %%
# Initialize a dictionary to identify the best configuration
best = {
                "id": None,
                "learning_rate": None,
                "max_depth": None,
                "n_estimators": None,
                "subsample": None,
                "mean_squared_error": 1000,
        }

# Iterate through the trails and update the best configuration
for trial in hpt_job.trials:
    # Keep track of the best outcome
    if float(trial.final_measurement.metrics[0].value) < best["mean_squared_error"]:
        best = {
                "id": trial.id,
                "learning_rate": float(trial.parameters[0].value),
                "max_depth": float(trial.parameters[1].value),
                "n_estimators": float(trial.parameters[2].value),
                "subsample": float(trial.parameters[3].value),
                "mean_squared_error": float(trial.final_measurement.metrics[0].value),
        }
        
# print details of the best configuration
print(best)
# Out:
# {'id': '8', 'learning_rate': 0.11117540967587292, 'max_depth': 3.0, 'n_estimators': 128.0, 'subsample': 0.3008784076506272, 'mean_squared_error': 14.953580245548158}

# %%
# Fetch the best model
BEST_MODEL_DIR = MODEL_DIR + "/" + best["id"] + "/model"

! gsutil ls {BEST_MODEL_DIR}
# Out:
# gs://ml-task-bucket/aiplatform-custom-job/8/model/
# gs://ml-task-bucket/aiplatform-custom-job/8/model/metrics.json
# gs://ml-task-bucket/aiplatform-custom-job/8/model/model.bst

# %%
! gsutil cp -r {BEST_MODEL_DIR} .
# Out:
# Copying gs://ml-task-bucket/aiplatform-custom-job/8/model/metrics.json...
# Copying gs://ml-task-bucket/aiplatform-custom-job/8/model/model.bst...
# / [2 files][ 64.7 KiB/ 64.7 KiB]
# Operation completed over 2 objects/64.7 KiB.

# %%
# Delete the hyperparameter tuning job
hpt_job.delete()

# Delete the Cloud Storage bucket
delete_bucket = False  # Set True to delete the bucket

if delete_bucket:
    ! gsutil rm -r $GCS_BUCKET

# Delete the locally generated files
# ! rm -rf boston-data-trainer/
! rm boston-data-trainer.tar.gz
# Out:
# Deleting HyperparameterTuningJob : projects/163391326695/locations/us-central1/hyperparameterTuningJobs/6199970525125541888
# HyperparameterTuningJob deleted. . Resource name: projects/163391326695/locations/us-central1/hyperparameterTuningJobs/6199970525125541888
# Deleting HyperparameterTuningJob resource: projects/163391326695/locations/us-central1/hyperparameterTuningJobs/6199970525125541888
# Delete HyperparameterTuningJob backing LRO: projects/163391326695/locations/us-central1/operations/4405152276797194240
# HyperparameterTuningJob resource projects/163391326695/locations/us-central1/hyperparameterTuningJobs/6199970525125541888 deleted.
